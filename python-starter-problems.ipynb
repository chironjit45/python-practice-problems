# %% [markdown]
# ## Problem-1: Write a program to find the length of the variable name.

# %%
name="Hello there"
print(len(name))

# %% [markdown]
# ## Problem-2: Write a program to find  the type of the variable name.

# %%
name="Hello there"
print(type(name))

# %% [markdown]
# ## Problem-3: Write a function that takes 2 number as arguments (ages of the two brothers) and find who is elder.

# %%
def age(x,y):
    if x>y:
        print("1st person is elder.")

    elif x<y: 
        print("2nd person is elder.")
    else:
        print("Both are same age.")

age(23,33)

# %% [markdown]
# ## Problem 4: Write a program to find the  index of 7. numbers=[3, 5, 1, 9, 7, 2, 8 ]

# %%
numbers=[3, 5, 1, 9, 7, 2, 8 ]
print(numbers.index(7))

# %% [markdown]
# ## Problem 5: Write a program to sort the numbers in ascending order.

# %%
numbers = [3, 5, 1, 9, 7, 2, 8]
numbers.sort()
print(numbers)

# %% [markdown]
# ## Problem-6: Write a function named "isLandscape" that takes 2 numbers (image width and height) as arguments and the function returns Landscape if the image width has a higher value than height. Returns Portrait otherwise

# %%
def isLandscape(width,height):
    if(width > height):
        print("Landscape")
    else: 
        print("Portrait")
isLandscape(1920,1080)

# %% [markdown]
# ## Problem-7: Write a function that takes 1 number as argument. The function should return “Fizz” if the number is divisible by 3, the function should return “Buzz” if the number is divisible by 5, the function should return “FizzBuzz” if the number is divisible by both 5 and 3, otherwise return “Not a Fizz-buzz number”

# %%
# type casting
my_input = int(input("Enter a number: "))

if my_input % 3 == 0 and my_input % 5 ==0:
    print("FizzBuzz")
elif my_input % 3 ==0:
    print("Fizz")
elif my_input % 5 ==0:
    print("Buzz")
else:
    print("Not a FizzBuzz number")

# %% [markdown]
# ## Problem-8: Guessing game
# ## Write a function that takes a number 1 to 9 from the user input (use input function inside a function). Store a number in a variable (let’s assume 6). If the input value is less than the variable, print (your guess is almost there), if the input value is greater than the variable, print - your guess is higher, if the input value and variable are equals, print - Your Guess Is Correct!

# %%
def input_function():
    store_number = 4
    input_value = int(input("Enter a number  between 1 to 9: "))
    if store_number > input_value: 
        print("your guess is almost there")
    elif store_number < input_value: 
        print("your guess is higher")
    else: 
        print("Your Guess Is Correct!")

input_function()

# %% [markdown]
# ## Problem 9: Find if 6 is available in the list. my_list = [4, 8, 7, 4,3,6,2,1,9]

# %%
my_list = [4, 8, 7, 4,3,6,2,1,9]
if 6 in my_list: 
    print("Yes, 6 is available in the list.")
else:
    print("6 is not available in the list.")

# %% [markdown]
# ## Problem-10: The list below is the collection of the ages of people from a village. Clean up the data and store only numbers in another list.

# %%
data_list = [13, 24, 'Karim', {'name': 'guru'}, 45, 17]
clean_list = []
for item in data_list:
    if type(item)==int or type(item)==float:
        clean_list.append(item)
print(clean_list)

# %% [markdown]
# # Problem-11: Find the most frequent character in the paragraph.
# ## rhyme = 'Twinkle, twinkle, little star. How I wonder what you are!

# %%
from collections import Counter
rhyme = 'Twinkle, twinkle, little star. How I wonder what you are!'

clean_rhyme = ''.join(char.lower() for char in rhyme if char.isalpha())

char_count = Counter(clean_rhyme)
most_fre_char = char_count.most_common(1)[0]

print(f"The most frequent character is {most_fre_char[0]}, which repeact is {most_fre_char[1]} times.")

# %% [markdown]
# ## Problem-12: Find the common items between the lists and make SUM of the new list items which are common between the lists. list1 = [3, 5, 7, 4, 8, 8], list2 = [4, 9, 8, 7, 1, 1, 13]

# %%
list1 = [3, 5, 7, 4, 8, 8]

list2 = [4, 9, 8, 7, 1, 1, 13]

common_items = set(list1) & set(list2)
print("Common items:",common_items)
print("Sum = ",sum(common_items))

# %% [markdown]
# ## Problem-13: Compare the two dictionaries and find the common items based on KEYs of the dictionaries. dict1 = {'age': 13, 'id': 12, 'address': 'Banani', 'course': 'Python'}, dict2 = {'address': 'Rupnagar', 'id': 25, 'course': 'MERN'}

# %%
dict1 = {'age': 13, 'id': 12, 'address': 'Banani', 'course': 'Python'}

dict2 = {'address': 'Rupnagar', 'id': 25, 'course': 'MERN'}

common_key = dict1.keys() & dict2.keys()
common_key

common_items = {}
for key in common_key:
    common_items[key] = (dict1[key],dict2[key])

print("Common items and their values.")
print(common_items)

# %% [markdown]
# ## Problem-14: Sort the list in DESCENDING order and find the subtraction of maximum and minimum numbers. list_1 = [4, 9, 8, 7, 5, 2, 13]

# %%
list_1 = [4, 9, 8, 7, 5, 2, 13]
list_1.sort(reverse=True)
max_num= max(list_1)
min_num = min(list_1)

subtraction = max_num + min_num
print(f"Sorted list(Decending Order: {list_1} and the subtraction(max & min) is: {subtraction}")

# %% [markdown]
# ## Problem-15: Write conditional statements to identify the student’s average marks. If any subject’s mark is less than 40, you should print FAILED instead of making average marks

# %%
lstudent_1 = [40, 35, 70, 90, 56]

student_2 = [57, 35, 80, 98, 46]

def Evaluate_student(marks):
    if  any(mark<40 for mark in marks):
        print("FAILED")
    else: 
        average_marks = sum(marks)/len(marks)
        print(f"The student average marks is: {average_marks}")
print("1st student result: ")
Evaluate_student([40,35,70,90,56])
print("2nd student result: ")
Evaluate_student([57,35,80,98,46])
